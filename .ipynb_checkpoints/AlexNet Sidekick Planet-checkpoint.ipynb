# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
#Expects timeseries.py in same folder as nb. 
from fastai.vision import *
from pathlib import Path
import pdb
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import fastai.callbacks.hooks

# %%
path = Path("planet")

# %%
src = (ImageItemList.from_csv(path,"train_v2.csv",folder="train-jpg",suffix=".jpg")
                    .random_split_by_pct(0.2)
                    .label_from_df(label_delim=" "))

# %%
tfms = get_transforms(flip_vert=True, max_lighting=0.1, max_zoom=1.05, max_warp=0.)
data = src.transform(tfms,size=128).databunch().normalize(imagenet_stats)

# %%
data = src.databunch().normalize(imagenet_stats)

# %%
data.show_batch()

# %%
models.alexnet()
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace)
#     (3): Dropout(p=0.5)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
class SidekickAlexNet(nn.Module):
    def __init__(self, num_classes=1000,width=8,pretrained=True):
        super().__init__()
        
        self.hero = create_body(models.alexnet,pretrained=pretrained)
        ml = [f for i,f in enumerate(next(self.hero.children()).children()) if i in [2,5,7,9,12]]
        self.hooks = fastai.callbacks.Hooks(ml,lambda m,i,o: o,detach=False)
        
        self.features = nn.ModuleList(
            [nn.Sequential(nn.Conv2d(3, 8*width, kernel_size=11, stride=4, padding=2),nn.ReLU(inplace=True),nn.MaxPool2d(kernel_size=3, stride=2)),
            nn.Sequential(nn.Conv2d(8*width + 64, 24 * width, kernel_size=5, padding=2),nn.ReLU(inplace=True),nn.MaxPool2d(kernel_size=3, stride=2)),
            nn.Sequential(nn.Conv2d(24*width + 192, 48 * width, kernel_size=3, padding=1),nn.ReLU(inplace=True)),
            nn.Sequential(nn.Conv2d(48*width + 384, 32 * width, kernel_size=3, padding=1),nn.ReLU(inplace=True)),
            nn.Sequential(nn.Conv2d(32*width + 256, 32 * width, kernel_size=3, padding=1),nn.ReLU(inplace=True),nn.MaxPool2d(kernel_size=3, stride=2))])
        
        self.classifier = create_head((32*width + 256)*2,num_classes)

    def forward(self, x):
        bs = x.shape[0]
        pt = self.hero(x)
        
        x = self.features[0](x)
        for f, a in zip(self.features[1:],self.hooks.stored):
            x = f(torch.cat([x,a],dim=1))
            
        x = torch.cat([x,pt],dim=1)    
        x = self.classifier(x)
        return x

# %%
learn = create_cnn(data,models.alexnet,metrics=[partial(accuracy_thresh,thresh=0.2),fbeta])

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 2.29E-02

# %%
learn.freeze()

# %%
learn.fit_one_cycle(10,1e-2)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       30.00% [3/10 02:57<06:53]
#     </div>
#
# <table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy_thresh</th>
#     <th>fbeta</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.138134</th>
#     <th>0.121214</th>
#     <th>0.935240</th>
#     <th>0.889129</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.134461</th>
#     <th>0.116662</th>
#     <th>0.938604</th>
#     <th>0.895733</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.130562</th>
#     <th>0.116919</th>
#     <th>0.944388</th>
#     <th>0.898041</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='506', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-5b6e06c0f4f3> in <module>
# ----> 1 learn.fit_one_cycle(10,1e-2)
#
# /opt/anaconda3/lib/python3.7/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, wd, callbacks, tot_epochs, start_epoch)
#      20     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start, tot_epochs=tot_epochs,
#      21                                        start_epoch=start_epoch))
# ---> 22     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      23
#      24 def lr_find(learn:Learner, start_lr:Floats=1e-7, end_lr:Floats=10, num_it:int=100, stop_div:bool=True, wd:float=None):
#
# /opt/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     176         callbacks = [cb(self) for cb in self.callback_fns] + listify(callbacks)
#     177         fit(epochs, self.model, self.loss_func, opt=self.opt, data=self.data, metrics=self.metrics,
# --> 178             callbacks=self.callbacks+callbacks)
#     179
#     180     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# /opt/anaconda3/lib/python3.7/site-packages/fastai/utils/mem.py in wrapper(*args, **kwargs)
#      78
#      79         try:
# ---> 80             return func(*args, **kwargs)
#      81         except Exception as e:
#      82             if ("CUDA out of memory" in str(e) or
#
# /opt/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py in fit(epochs, model, loss_func, opt, data, callbacks, metrics)
#      86             cb_handler.set_dl(data.train_dl)
#      87             cb_handler.on_epoch_begin()
# ---> 88             for xb,yb in progress_bar(data.train_dl, parent=pbar):
#      89                 xb, yb = cb_handler.on_batch_begin(xb, yb)
#      90                 loss = loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#
# /opt/anaconda3/lib/python3.7/site-packages/fastprogress/fastprogress.py in __iter__(self)
#      64         self.update(0)
#      65         try:
# ---> 66             for i,o in enumerate(self._gen):
#      67                 yield o
#      68                 if self.auto_update: self.update(i+1)
#
# /opt/anaconda3/lib/python3.7/site-packages/fastai/basic_data.py in __iter__(self)
#      73     def __iter__(self):
#      74         "Process and returns items from `DataLoader`."
# ---> 75         for b in self.dl: yield self.proc_batch(b)
#      76
#      77     @classmethod
#
# /opt/anaconda3/lib/python3.7/site-packages/fastai/basic_data.py in proc_batch(self, b)
#      67     def proc_batch(self,b:Tensor)->Tensor:
#      68         "Process batch `b` of `TensorImage`."
# ---> 69         b = to_device(b, self.device)
#      70         for f in listify(self.tfms): b = f(b)
#      71         return b
#
# /opt/anaconda3/lib/python3.7/site-packages/fastai/torch_core.py in to_device(b, device)
#     109     "Recursively put `b` on `device`."
#     110     device = ifnone(device, defaults.device)
# --> 111     if is_listy(b): return [to_device(o, device) for o in b]
#     112     if is_dict(b): return {k: to_device(v, device) for k, v in b.items()}
#     113     return b.to(device)
#
# /opt/anaconda3/lib/python3.7/site-packages/fastai/torch_core.py in <listcomp>(.0)
#     109     "Recursively put `b` on `device`."
#     110     device = ifnone(device, defaults.device)
# --> 111     if is_listy(b): return [to_device(o, device) for o in b]
#     112     if is_dict(b): return {k: to_device(v, device) for k, v in b.items()}
#     113     return b.to(device)
#
# /opt/anaconda3/lib/python3.7/site-packages/fastai/torch_core.py in to_device(b, device)
#     111     if is_listy(b): return [to_device(o, device) for o in b]
#     112     if is_dict(b): return {k: to_device(v, device) for k, v in b.items()}
# --> 113     return b.to(device)
#     114
#     115 def data_collate(batch:ItemsList)->Tensor:
#
# KeyboardInterrupt:

# %%
learn.unfreeze()
learn.fit_one_cycle(10,1e-5)
# Out:
# Total time: 05:38 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy_thresh</th>
#     <th>fbeta</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.107738</th>
#     <th>0.101498</th>
#     <th>0.944766</th>
#     <th>0.910626</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.103193</th>
#     <th>0.098746</th>
#     <th>0.947615</th>
#     <th>0.912832</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.104720</th>
#     <th>0.096586</th>
#     <th>0.948509</th>
#     <th>0.915521</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.100665</th>
#     <th>0.095289</th>
#     <th>0.948254</th>
#     <th>0.916802</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.098742</th>
#     <th>0.094528</th>
#     <th>0.950979</th>
#     <th>0.916340</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.092739</th>
#     <th>0.094011</th>
#     <th>0.951582</th>
#     <th>0.917731</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.097046</th>
#     <th>0.093191</th>
#     <th>0.952352</th>
#     <th>0.917999</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.094472</th>
#     <th>0.093089</th>
#     <th>0.951219</th>
#     <th>0.918848</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.095194</th>
#     <th>0.093036</th>
#     <th>0.952105</th>
#     <th>0.918396</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.093651</th>
#     <th>0.093075</th>
#     <th>0.951313</th>
#     <th>0.918518</th>
#   </tr>
# </table>

# %%
learnSK = Learner(data,SidekickAlexNet(data.train_ds.c,width=8),metrics=[partial(accuracy_thresh,thresh=0.2),fbeta])
learnSK.split([learnSK.model.hero,learnSK.model.features[0],learnSK.model.classifier])

# %%
learnSK.model(next(iter(data.train_dl))[0]).shape
# Out:
# torch.Size([64, 17])

# %%
learnSK.freeze_to(1)

# %%
learnSK.fit_one_cycle(20,1e-3)
# Out:
# Total time: 10:54 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy_thresh</th>
#     <th>fbeta</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.528912</th>
#     <th>0.487247</th>
#     <th>0.224925</th>
#     <th>0.494937</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.152607</th>
#     <th>0.125132</th>
#     <th>0.943436</th>
#     <th>0.906300</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.113452</th>
#     <th>0.103896</th>
#     <th>0.946285</th>
#     <th>0.905987</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.111131</th>
#     <th>0.103927</th>
#     <th>0.948952</th>
#     <th>0.908984</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.105829</th>
#     <th>0.099299</th>
#     <th>0.946154</th>
#     <th>0.912928</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.105695</th>
#     <th>0.097436</th>
#     <th>0.949468</th>
#     <th>0.913086</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.103590</th>
#     <th>0.098231</th>
#     <th>0.949482</th>
#     <th>0.911673</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.100196</th>
#     <th>0.095958</th>
#     <th>0.954031</th>
#     <th>0.915566</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.100302</th>
#     <th>0.093235</th>
#     <th>0.953115</th>
#     <th>0.918139</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.094035</th>
#     <th>0.092548</th>
#     <th>0.952418</th>
#     <th>0.918282</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.093794</th>
#     <th>0.094822</th>
#     <th>0.953094</th>
#     <th>0.918829</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.091800</th>
#     <th>0.091823</th>
#     <th>0.955601</th>
#     <th>0.919999</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.089862</th>
#     <th>0.091609</th>
#     <th>0.953552</th>
#     <th>0.919576</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.089259</th>
#     <th>0.091097</th>
#     <th>0.954489</th>
#     <th>0.921055</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.089771</th>
#     <th>0.091051</th>
#     <th>0.954838</th>
#     <th>0.922045</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.088980</th>
#     <th>0.089526</th>
#     <th>0.954394</th>
#     <th>0.922216</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.087561</th>
#     <th>0.089919</th>
#     <th>0.954191</th>
#     <th>0.922542</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.086014</th>
#     <th>0.089495</th>
#     <th>0.955477</th>
#     <th>0.922213</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.084740</th>
#     <th>0.089703</th>
#     <th>0.954351</th>
#     <th>0.922097</th>
#   </tr>
#   <tr>
#     <th>20</th>
#     <th>0.086432</th>
#     <th>0.090590</th>
#     <th>0.954954</th>
#     <th>0.922494</th>
#   </tr>
# </table>

# %%
learnSK.save("sz128")

# %%
out = []
for x in np.linspace(0.1,0.5,10):
    out.append((x,learnSK.validate(dl=data.valid_dl,metrics=[partial(accuracy_thresh,thresh=x),partial(fbeta,thresh=x)])))
out
# Out:
# [(0.1, [0.08587874, tensor(0.9357), tensor(0.9184)]),
#  (0.14444444444444446, [0.08587874, tensor(0.9477), tensor(0.9234)]),
#  (0.18888888888888888, [0.08587874, tensor(0.9548), tensor(0.9246)]),
#  (0.23333333333333334, [0.08587874, tensor(0.9593), tensor(0.9243)]),
#  (0.2777777777777778, [0.08587874, tensor(0.9622), tensor(0.9220)]),
#  (0.32222222222222224, [0.08587874, tensor(0.9640), tensor(0.9185)]),
#  (0.3666666666666667, [0.08587874, tensor(0.9652), tensor(0.9147)]),
#  (0.4111111111111111, [0.08587874, tensor(0.9661), tensor(0.9099)]),
#  (0.4555555555555556, [0.08587874, tensor(0.9666), tensor(0.9054)]),
#  (0.5, [0.08587874, tensor(0.9667), tensor(0.8999)])]

# %%
dataL = src.transform(tfms,size=256).databunch().normalize(imagenet_stats)
learnSK.data = dataL

# %%
learnSK.fit_one_cycle(10,1e-4)
# Out:
# Total time: 10:23 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy_thresh</th>
#     <th>fbeta</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.096549</th>
#     <th>0.094032</th>
#     <th>0.949744</th>
#     <th>0.916732</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.088793</th>
#     <th>0.090662</th>
#     <th>0.953900</th>
#     <th>0.920405</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.091340</th>
#     <th>0.088139</th>
#     <th>0.953406</th>
#     <th>0.922319</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.086278</th>
#     <th>0.087251</th>
#     <th>0.954860</th>
#     <th>0.923700</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.089482</th>
#     <th>0.087094</th>
#     <th>0.953871</th>
#     <th>0.922571</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.088707</th>
#     <th>0.085897</th>
#     <th>0.956320</th>
#     <th>0.925627</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.087397</th>
#     <th>0.086122</th>
#     <th>0.955346</th>
#     <th>0.924630</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.085799</th>
#     <th>0.085921</th>
#     <th>0.955783</th>
#     <th>0.924853</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.087492</th>
#     <th>0.085974</th>
#     <th>0.955688</th>
#     <th>0.924920</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.087900</th>
#     <th>0.085879</th>
#     <th>0.955913</th>
#     <th>0.924249</th>
#   </tr>
# </table>

# %%
test = ImageItemList.from_folder(path/'test-jpg').add(ImageItemList.from_folder(path/'test-jpg-additional'))
#test = test.no_split().label_const().databunch()
testDL = torch.utils.data.DataLoader(test,collate_fn=data_collate,batch_size=64)

# %%
fnames = [f.name[:-4] for f in test.items]

# %%
learnSK.model.eval()
learnSK.model.cuda()
preds = []
for x in progress_bar(iter(testDL)):
    p = learnSK.model(x.cuda())
    p = torch.sigmoid(p)
    preds += [" ".join([data.classes[i] for i,c in enumerate(r) if c >= 0.2]) for r in p]
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='957' class='' max='957', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [957/957 03:33<00:00]
#     </div>

# %%
outDF = pd.DataFrame({"image_name": fnames,"tags":preds})

# %%
outDF.head()
# Out:
#    image_name                                               tags
# 0  test_35779  agriculture cloudy haze partly_cloudy primary ...
# 1  test_22155               agriculture clear haze primary water
# 2  test_39245                                             cloudy
# 3  test_24757                                 clear cloudy water
# 4  test_39827                                cloudy haze primary

# %%
outDF.to_csv("out.csv",index=False)
